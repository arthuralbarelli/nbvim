# %%
from PIL import Image, ImageDraw
from IPython.display import display

image = Image.new("RGB", (48, 24), "#101b3d")
draw = ImageDraw.Draw(image)
draw.ellipse((6, 4, 22, 20), fill="#ffb000")
draw.rectangle((27, 6, 42, 18), fill="#35d07f")
draw.line((3, 21, 45, 2), fill="#ff5c8a", width=2)
display(image)
